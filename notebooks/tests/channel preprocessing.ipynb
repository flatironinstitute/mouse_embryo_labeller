# %%
from mouse_embryo_labeller import tools

# %%
tools.preprocess_channel_data()
# Out:
# Stored empty nucleus collection ../channels_example/nuclei.json
# ::: found timestamp labels file /Users/awatters/misc/LisaBrown/pole_cell/560/LabelDownSample_out_stack0_chan1_camFuse_00000.tif
# ::: timestamp {'identity': 0, 'json_path': 'ts0.json', 'npz_path': 'ts0.npz'}
# ::: found timestamp labels file /Users/awatters/misc/LisaBrown/pole_cell/560/LabelDownSample_out_stack0_chan1_camFuse_00001.tif
# ::: timestamp {'identity': 1, 'json_path': 'ts1.json', 'npz_path': 'ts1.npz'}
# ::: found timestamp labels file /Users/awatters/misc/LisaBrown/pole_cell/560/LabelDownSample_out_stack0_chan1_camFuse_00002.tif
# ::: timestamp {'identity': 2, 'json_path': 'ts2.json', 'npz_path': 'ts2.npz'}
# ::: found timestamp labels file /Users/awatters/misc/LisaBrown/pole_cell/560/LabelDownSample_out_stack0_chan1_camFuse_00003.tif
# ::: timestamp {'identity': 3, 'json_path': 'ts3.json', 'npz_path': 'ts3.npz'}
# ...

# %%
1
# Out:
# 1
